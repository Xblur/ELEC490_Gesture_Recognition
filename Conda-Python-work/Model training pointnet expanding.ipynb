# %%
# Data Processing and model code
# import necessary packages

import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
import time
import datetime
from pathlib import Path
import glob

tf.random.set_seed(1234)

# path="wiki_crop/00"
# load dataset
with open("labaled_data.json", "r") as outfile:
            data = json.load(outfile)
        
with open("labaled_data.json", "r") as outfile:
    our_data = json.load(outfile)

data.update(our_data)
classes = set()
for i in data:
    classes.add(data.get(i)[1])
classes = list(classes)

# %%
# %matplotlib notebook
points = np.array(data.get(list(data.keys())[2])[0])
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(points[:, 0], points[:, 1], points[:, 2])
ax.set_axis_off()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
def parse_split_dataset(data, classes, num_points=478):

    train_points = []
    train_labels = []
    test_points = []
    test_labels = []
    class_map = classes

    for i in enumerate(list(data.keys())):
        if i[0] < int(len(list(data.keys()))*0.8):
            train_points.append(data.get(i[1])[0])
            train_labels.append(classes.index(data.get(i[1])[1]))
        else:
            test_points.append(data.get(i[1])[0])
            test_labels.append(classes.index(data.get(i[1])[1]))
        
    return (
        np.array(train_points),
        np.array(test_points),
        np.array(train_labels),
        np.array(test_labels),
        class_map,
    )

# %%
NUM_POINTS = 478
NUM_CLASSES = len(classes)
BATCH_SIZE = 16

train_points, test_points, train_labels, test_labels, CLASS_MAP = parse_split_dataset(data, classes, NUM_POINTS)

# %%
def augment(points, label):
    # jitter points
    points += tf.random.uniform(points.shape, -0.005, 0.005, dtype=tf.float64)
    # shuffle points
    points = tf.random.shuffle(points)
    return points, label


train_dataset = tf.data.Dataset.from_tensor_slices((train_points, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_points, test_labels))

train_dataset = train_dataset.shuffle(len(train_points)).map(augment).batch(BATCH_SIZE)
test_dataset = test_dataset.shuffle(len(test_points)).batch(BATCH_SIZE)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((None, 478, 3), (None,)), types: (tf.float64, tf.int32)>

# %%
def conv_bn(x, filters):
    x = layers.Conv1D(filters, kernel_size=1, padding="valid")(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)


def dense_bn(x, filters):
    x = layers.Dense(filters)(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)

# %%
class OrthogonalRegularizer(keras.regularizers.Regularizer):
    def __init__(self, num_features, l2reg=0.001):
        super().__init__()
        self.num_features = num_features
        self.l2reg = l2reg
        self.eye = tf.eye(num_features)

    def __call__(self, x):
        x = tf.reshape(x, (-1, self.num_features, self.num_features))
        xxt = tf.tensordot(x, x, axes=(2, 2))
        xxt = tf.reshape(xxt, (-1, self.num_features, self.num_features))
        return tf.reduce_sum(self.l2reg * tf.square(xxt - self.eye))
    
    def get_config(self):
        config = super().get_config()
        config.update({"num_features": self.num_features, "l2reg_strength": self.l2reg})
        return config

# %%
def tnet(inputs, num_features):

    # Initalise bias as the indentity matrix
    bias = keras.initializers.Constant(np.eye(num_features).flatten())
    reg = OrthogonalRegularizer(num_features)

    x = conv_bn(inputs, 32)
    x = conv_bn(x, 128)
    x = conv_bn(x, 256)
    x = conv_bn(x, 1028)
    x = layers.GlobalMaxPooling1D()(x)
    x = dense_bn(x, 512)
    x = dense_bn(x, 256)
    x = dense_bn(x, 128)
    x = layers.Dense(
        num_features * num_features,
        kernel_initializer="zeros",
        bias_initializer=bias,
        activity_regularizer=reg,
    )(x)
    feat_T = layers.Reshape((num_features, num_features))(x)
    # Apply affine transformation to input features
    return layers.Dot(axes=(2, 1))([inputs, feat_T])

# %%
#Point net model
inputs = keras.Input(shape=(NUM_POINTS, 3))

x = tnet(inputs, 3)
x = conv_bn(x, 32)
x = conv_bn(x, 32)
x = tnet(x, 32)
x = conv_bn(x, 32)
x = conv_bn(x, 64)
x = conv_bn(x, 128)
x = conv_bn(x, 512)
x = layers.GlobalMaxPooling1D()(x)
x = dense_bn(x, 512)
x = dense_bn(x, 256)
x = layers.Dropout(0.3)(x)
x = dense_bn(x, 128)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)
model_name = "./Pointnet_expanded_our2"
model = keras.Model(inputs=inputs, outputs=outputs, name=model_name)
model.summary()
# Out:
# Model: "./Pointnet_expanded_our2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 478, 3)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 478, 32)      128         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 478, 32)      128         conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 478, 32)      0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 478, 128)     4224        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 478, 128)     512         conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 478, 128)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 478, 256)     33024       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 478, 256)     1024        conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 478, 256)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 478, 1028)    264196      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 478, 1028)    4112        conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 478, 1028)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 1028)         0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          526848      global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 256)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128)          512         dense_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 9)            1161        activation_6[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 3, 3)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 478, 3)       0           input_1[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 478, 32)      128         dot[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 478, 32)      128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 478, 32)      0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 478, 32)      1056        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 478, 32)      128         conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 478, 32)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 478, 32)      1056        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 478, 32)      128         conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 478, 32)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 478, 128)     4224        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 478, 128)     512         conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 478, 128)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 478, 256)     33024       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 478, 256)     1024        conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 478, 256)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 478, 1028)    264196      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 478, 1028)    4112        conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 478, 1028)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 1028)         0           activation_12[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          526848      global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 512)          2048        dense_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 512)          0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          131328      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256)          1024        dense_5[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 256)          0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          32896       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128)          512         dense_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128)          0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1024)         132096      activation_15[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 32, 32)       0           dense_7[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 478, 32)      0           activation_8[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 478, 32)      1056        dot_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 478, 32)      128         conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 478, 32)      0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 478, 64)      2112        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 478, 64)      256         conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 478, 64)      0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 478, 128)     8320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 478, 128)     512         conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 478, 128)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 478, 512)     66048       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 478, 512)     2048        conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 478, 512)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 512)          0           activation_19[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 512)          262656      global_max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 512)          2048        dense_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 512)          0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 256)          131328      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256)          1024        dense_9[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256)          0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           activation_21[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          32896       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128)          512         dense_10[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 128)          0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           activation_22[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            258         dropout_1[0][0]
# ==================================================================================================
# Total params: 2,650,835
# Trainable params: 2,638,083
# Non-trainable params: 12,752
# __________________________________________________________________________________________________

# %%
try:
    model.load_weights(model_name)
except:
    print("no model data")

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=["sparse_categorical_accuracy"],
)

checkpoint_filepath = "./checkpoint_"+model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_sparse_categorical_accuracy',
    mode='max',
    save_best_only=True)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + model_name
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
model.fit(train_dataset, epochs=200, validation_data=test_dataset, callbacks=[model_checkpoint_callback,tensorboard_callback])

# model.load_weights(checkpoint_filepath)
model.save_weights(model_name)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... <__main__.OrthogonalRegularizer object at 0x00000164DE851A60> does not implement get_config()
# Epoch 1/200
# 31/31 [==============================] - 7s 115ms/step - loss: 0.8453 - sparse_categorical_accuracy: 0.8652 - val_loss: 2.4070 - val_sparse_categorical_accuracy: 0.6613
# Epoch 2/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.8657 - sparse_categorical_accuracy: 0.8482 - val_loss: 1.2914 - val_sparse_categorical_accuracy: 0.6935
# Epoch 3/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.8699 - sparse_categorical_accuracy: 0.8624 - val_loss: 1.7926 - val_sparse_categorical_accuracy: 0.7177
# Epoch 4/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8418 - sparse_categorical_accuracy: 0.8623 - val_loss: 1.5136 - val_sparse_categorical_accuracy: 0.6210
# Epoch 5/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7804 - sparse_categorical_accuracy: 0.9133 - val_loss: 1.5399 - val_sparse_categorical_accuracy: 0.6613
# Epoch 6/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8616 - sparse_categorical_accuracy: 0.8423 - val_loss: 1.9050 - val_sparse_categorical_accuracy: 0.6048
# Epoch 7/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8577 - sparse_categorical_accuracy: 0.8629 - val_loss: 1.3010 - val_sparse_categorical_accuracy: 0.7177
# Epoch 8/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7878 - sparse_categorical_accuracy: 0.8769 - val_loss: 1.5565 - val_sparse_categorical_accuracy: 0.7258
# Epoch 9/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8633 - sparse_categorical_accuracy: 0.8477 - val_loss: 1.7045 - val_sparse_categorical_accuracy: 0.6210
# Epoch 10/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8880 - sparse_categorical_accuracy: 0.8523 - val_loss: 1.3676 - val_sparse_categorical_accuracy: 0.6694
# Epoch 11/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.9424 - sparse_categorical_accuracy: 0.8327 - val_loss: 1.3556 - val_sparse_categorical_accuracy: 0.6855
# Epoch 12/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8415 - sparse_categorical_accuracy: 0.8548 - val_loss: 1.7424 - val_sparse_categorical_accuracy: 0.6613
# Epoch 13/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7933 - sparse_categorical_accuracy: 0.8956 - val_loss: 1.3516 - val_sparse_categorical_accuracy: 0.7016
# Epoch 14/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8445 - sparse_categorical_accuracy: 0.8763 - val_loss: 1.7829 - val_sparse_categorical_accuracy: 0.5726
# Epoch 15/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.9628 - sparse_categorical_accuracy: 0.8216 - val_loss: 1.5768 - val_sparse_categorical_accuracy: 0.6210
# Epoch 16/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.8542 - sparse_categorical_accuracy: 0.8840 - val_loss: 1.3432 - val_sparse_categorical_accuracy: 0.7419
# Epoch 17/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.9002 - sparse_categorical_accuracy: 0.8524 - val_loss: 1.2317 - val_sparse_categorical_accuracy: 0.7016
# Epoch 18/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8287 - sparse_categorical_accuracy: 0.8834 - val_loss: 1.3410 - val_sparse_categorical_accuracy: 0.6855
# Epoch 19/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8025 - sparse_categorical_accuracy: 0.8760 - val_loss: 1.5495 - val_sparse_categorical_accuracy: 0.6694
# Epoch 20/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7658 - sparse_categorical_accuracy: 0.9096 - val_loss: 1.4075 - val_sparse_categorical_accuracy: 0.6613
# Epoch 21/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8071 - sparse_categorical_accuracy: 0.8794 - val_loss: 1.6749 - val_sparse_categorical_accuracy: 0.6532
# Epoch 22/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7707 - sparse_categorical_accuracy: 0.8966 - val_loss: 1.5054 - val_sparse_categorical_accuracy: 0.6855
# Epoch 23/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8485 - sparse_categorical_accuracy: 0.8574 - val_loss: 1.4525 - val_sparse_categorical_accuracy: 0.6613
# Epoch 24/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7717 - sparse_categorical_accuracy: 0.9071 - val_loss: 1.5577 - val_sparse_categorical_accuracy: 0.7177
# Epoch 25/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7424 - sparse_categorical_accuracy: 0.9146 - val_loss: 1.5210 - val_sparse_categorical_accuracy: 0.6694
# Epoch 26/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8280 - sparse_categorical_accuracy: 0.8640 - val_loss: 1.6050 - val_sparse_categorical_accuracy: 0.7016
# Epoch 27/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8506 - sparse_categorical_accuracy: 0.8743 - val_loss: 1.4023 - val_sparse_categorical_accuracy: 0.7177
# Epoch 28/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8243 - sparse_categorical_accuracy: 0.8680 - val_loss: 2.1135 - val_sparse_categorical_accuracy: 0.6210
# Epoch 29/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8206 - sparse_categorical_accuracy: 0.8703 - val_loss: 1.6258 - val_sparse_categorical_accuracy: 0.6371
# Epoch 30/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7722 - sparse_categorical_accuracy: 0.9155 - val_loss: 2.0597 - val_sparse_categorical_accuracy: 0.6129
# Epoch 31/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8101 - sparse_categorical_accuracy: 0.8692 - val_loss: 1.3486 - val_sparse_categorical_accuracy: 0.6532
# Epoch 32/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8604 - sparse_categorical_accuracy: 0.8465 - val_loss: 1.7474 - val_sparse_categorical_accuracy: 0.7177
# Epoch 33/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.9339 - sparse_categorical_accuracy: 0.8104 - val_loss: 1.8805 - val_sparse_categorical_accuracy: 0.6613
# Epoch 34/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8260 - sparse_categorical_accuracy: 0.8773 - val_loss: 2.5494 - val_sparse_categorical_accuracy: 0.6210
# Epoch 35/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7559 - sparse_categorical_accuracy: 0.9216 - val_loss: 1.4218 - val_sparse_categorical_accuracy: 0.6371
# Epoch 36/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.8436 - sparse_categorical_accuracy: 0.8733 - val_loss: 1.4873 - val_sparse_categorical_accuracy: 0.6210
# Epoch 37/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7908 - sparse_categorical_accuracy: 0.8700 - val_loss: 1.7879 - val_sparse_categorical_accuracy: 0.6290
# Epoch 38/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7683 - sparse_categorical_accuracy: 0.8879 - val_loss: 1.7749 - val_sparse_categorical_accuracy: 0.5726
# Epoch 39/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.8439 - sparse_categorical_accuracy: 0.8815 - val_loss: 1.6471 - val_sparse_categorical_accuracy: 0.6532
# Epoch 40/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.7166 - sparse_categorical_accuracy: 0.9350 - val_loss: 1.8026 - val_sparse_categorical_accuracy: 0.5968
# Epoch 41/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.7720 - sparse_categorical_accuracy: 0.9017 - val_loss: 1.4870 - val_sparse_categorical_accuracy: 0.7016
# Epoch 42/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7843 - sparse_categorical_accuracy: 0.8991 - val_loss: 1.8613 - val_sparse_categorical_accuracy: 0.5968
# Epoch 43/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.8101 - sparse_categorical_accuracy: 0.8878 - val_loss: 2.0142 - val_sparse_categorical_accuracy: 0.6290
# Epoch 44/200
# 31/31 [==============================] - 2s 65ms/step - loss: 0.7537 - sparse_categorical_accuracy: 0.9132 - val_loss: 1.3691 - val_sparse_categorical_accuracy: 0.7258
# Epoch 45/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.7790 - sparse_categorical_accuracy: 0.9061 - val_loss: 1.8396 - val_sparse_categorical_accuracy: 0.6452
# Epoch 46/200
# 31/31 [==============================] - 4s 124ms/step - loss: 0.7991 - sparse_categorical_accuracy: 0.8708 - val_loss: 1.8713 - val_sparse_categorical_accuracy: 0.6290
# Epoch 47/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7516 - sparse_categorical_accuracy: 0.9053 - val_loss: 2.0124 - val_sparse_categorical_accuracy: 0.6774
# Epoch 48/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7770 - sparse_categorical_accuracy: 0.9119 - val_loss: 1.7166 - val_sparse_categorical_accuracy: 0.6290
# Epoch 49/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8472 - sparse_categorical_accuracy: 0.8617 - val_loss: 1.4963 - val_sparse_categorical_accuracy: 0.7661
# Epoch 50/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7632 - sparse_categorical_accuracy: 0.8940 - val_loss: 1.4984 - val_sparse_categorical_accuracy: 0.6452
# Epoch 51/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8355 - sparse_categorical_accuracy: 0.8628 - val_loss: 1.9614 - val_sparse_categorical_accuracy: 0.5968
# Epoch 52/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.7439 - sparse_categorical_accuracy: 0.9099 - val_loss: 1.9858 - val_sparse_categorical_accuracy: 0.5645
# Epoch 53/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8979 - sparse_categorical_accuracy: 0.8394 - val_loss: 1.3888 - val_sparse_categorical_accuracy: 0.6129
# Epoch 54/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7884 - sparse_categorical_accuracy: 0.8744 - val_loss: 1.4521 - val_sparse_categorical_accuracy: 0.6048
# Epoch 55/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.7652 - sparse_categorical_accuracy: 0.9080 - val_loss: 1.8756 - val_sparse_categorical_accuracy: 0.7097
# Epoch 56/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7362 - sparse_categorical_accuracy: 0.9153 - val_loss: 1.7634 - val_sparse_categorical_accuracy: 0.6774
# Epoch 57/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7964 - sparse_categorical_accuracy: 0.8709 - val_loss: 1.5342 - val_sparse_categorical_accuracy: 0.6855
# Epoch 58/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8205 - sparse_categorical_accuracy: 0.8532 - val_loss: 2.6924 - val_sparse_categorical_accuracy: 0.5081
# Epoch 59/200
# 31/31 [==============================] - 2s 62ms/step - loss: 0.7446 - sparse_categorical_accuracy: 0.9319 - val_loss: 1.5672 - val_sparse_categorical_accuracy: 0.6935
# Epoch 60/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7174 - sparse_categorical_accuracy: 0.9289 - val_loss: 1.3789 - val_sparse_categorical_accuracy: 0.7097
# Epoch 61/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7906 - sparse_categorical_accuracy: 0.8867 - val_loss: 1.5880 - val_sparse_categorical_accuracy: 0.7097
# Epoch 62/200
# 31/31 [==============================] - 2s 53ms/step - loss: 0.7535 - sparse_categorical_accuracy: 0.9192 - val_loss: 1.4718 - val_sparse_categorical_accuracy: 0.7339
# Epoch 63/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7183 - sparse_categorical_accuracy: 0.9273 - val_loss: 2.0324 - val_sparse_categorical_accuracy: 0.6290
# Epoch 64/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.7895 - sparse_categorical_accuracy: 0.8884 - val_loss: 1.7125 - val_sparse_categorical_accuracy: 0.6290
# Epoch 65/200
# 31/31 [==============================] - 3s 88ms/step - loss: 0.7404 - sparse_categorical_accuracy: 0.9149 - val_loss: 1.5359 - val_sparse_categorical_accuracy: 0.6129
# Epoch 66/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7844 - sparse_categorical_accuracy: 0.8939 - val_loss: 1.5105 - val_sparse_categorical_accuracy: 0.6855
# Epoch 67/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.9379 - val_loss: 2.0136 - val_sparse_categorical_accuracy: 0.6935
# Epoch 68/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7216 - sparse_categorical_accuracy: 0.9215 - val_loss: 1.6331 - val_sparse_categorical_accuracy: 0.6774
# Epoch 69/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.9337 - val_loss: 1.6201 - val_sparse_categorical_accuracy: 0.6694
# Epoch 70/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7986 - sparse_categorical_accuracy: 0.8915 - val_loss: 2.2717 - val_sparse_categorical_accuracy: 0.6210
# Epoch 71/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7179 - sparse_categorical_accuracy: 0.9305 - val_loss: 1.2510 - val_sparse_categorical_accuracy: 0.7339
# Epoch 72/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7404 - sparse_categorical_accuracy: 0.9303 - val_loss: 1.5604 - val_sparse_categorical_accuracy: 0.6694
# Epoch 73/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.7092 - sparse_categorical_accuracy: 0.9254 - val_loss: 1.8345 - val_sparse_categorical_accuracy: 0.6532
# Epoch 74/200
# 31/31 [==============================] - 2s 65ms/step - loss: 0.7233 - sparse_categorical_accuracy: 0.9302 - val_loss: 1.7735 - val_sparse_categorical_accuracy: 0.6532
# Epoch 75/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7037 - sparse_categorical_accuracy: 0.9392 - val_loss: 1.6875 - val_sparse_categorical_accuracy: 0.6532
# Epoch 76/200
# 31/31 [==============================] - 1s 48ms/step - loss: 0.7410 - sparse_categorical_accuracy: 0.9109 - val_loss: 1.9201 - val_sparse_categorical_accuracy: 0.5645
# Epoch 77/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.8337 - sparse_categorical_accuracy: 0.8794 - val_loss: 1.5482 - val_sparse_categorical_accuracy: 0.6210
# Epoch 78/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.7989 - sparse_categorical_accuracy: 0.8948 - val_loss: 1.6292 - val_sparse_categorical_accuracy: 0.6855
# Epoch 79/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7181 - sparse_categorical_accuracy: 0.9267 - val_loss: 1.4195 - val_sparse_categorical_accuracy: 0.7097
# Epoch 80/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7126 - sparse_categorical_accuracy: 0.9332 - val_loss: 1.4865 - val_sparse_categorical_accuracy: 0.6855
# Epoch 81/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7458 - sparse_categorical_accuracy: 0.9135 - val_loss: 1.4308 - val_sparse_categorical_accuracy: 0.7097
# Epoch 82/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.7105 - sparse_categorical_accuracy: 0.9190 - val_loss: 1.4239 - val_sparse_categorical_accuracy: 0.7903
# Epoch 83/200
# 31/31 [==============================] - 2s 53ms/step - loss: 0.6582 - sparse_categorical_accuracy: 0.9710 - val_loss: 1.8017 - val_sparse_categorical_accuracy: 0.6613
# Epoch 84/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.7104 - sparse_categorical_accuracy: 0.9312 - val_loss: 1.6924 - val_sparse_categorical_accuracy: 0.7016
# Epoch 85/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7725 - sparse_categorical_accuracy: 0.9010 - val_loss: 2.5958 - val_sparse_categorical_accuracy: 0.6290
# Epoch 86/200
# 31/31 [==============================] - 2s 53ms/step - loss: 0.7800 - sparse_categorical_accuracy: 0.8854 - val_loss: 3.9161 - val_sparse_categorical_accuracy: 0.5565
# Epoch 87/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7054 - sparse_categorical_accuracy: 0.9353 - val_loss: 1.6447 - val_sparse_categorical_accuracy: 0.6694
# Epoch 88/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7533 - sparse_categorical_accuracy: 0.9041 - val_loss: 1.4704 - val_sparse_categorical_accuracy: 0.6774
# Epoch 89/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7391 - sparse_categorical_accuracy: 0.8982 - val_loss: 1.5131 - val_sparse_categorical_accuracy: 0.6371
# Epoch 90/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7179 - sparse_categorical_accuracy: 0.9314 - val_loss: 1.8005 - val_sparse_categorical_accuracy: 0.6855
# Epoch 91/200
# 31/31 [==============================] - 2s 62ms/step - loss: 0.7557 - sparse_categorical_accuracy: 0.8927 - val_loss: 1.5227 - val_sparse_categorical_accuracy: 0.6452
# Epoch 92/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7030 - sparse_categorical_accuracy: 0.9326 - val_loss: 2.1519 - val_sparse_categorical_accuracy: 0.6129
# Epoch 93/200
# 31/31 [==============================] - 2s 78ms/step - loss: 0.7590 - sparse_categorical_accuracy: 0.8973 - val_loss: 2.3508 - val_sparse_categorical_accuracy: 0.6452
# Epoch 94/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.7038 - sparse_categorical_accuracy: 0.9131 - val_loss: 1.8461 - val_sparse_categorical_accuracy: 0.5323
# Epoch 95/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.7464 - sparse_categorical_accuracy: 0.9252 - val_loss: 2.0031 - val_sparse_categorical_accuracy: 0.6774
# Epoch 96/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7467 - sparse_categorical_accuracy: 0.9170 - val_loss: 1.5000 - val_sparse_categorical_accuracy: 0.6452
# Epoch 97/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6622 - sparse_categorical_accuracy: 0.9444 - val_loss: 1.9508 - val_sparse_categorical_accuracy: 0.6210
# Epoch 98/200
# 31/31 [==============================] - 1s 48ms/step - loss: 0.7259 - sparse_categorical_accuracy: 0.9297 - val_loss: 1.5105 - val_sparse_categorical_accuracy: 0.6371
# Epoch 99/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7580 - sparse_categorical_accuracy: 0.9221 - val_loss: 2.1532 - val_sparse_categorical_accuracy: 0.7177
# Epoch 100/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6720 - sparse_categorical_accuracy: 0.9474 - val_loss: 1.4974 - val_sparse_categorical_accuracy: 0.7016
# Epoch 101/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.7665 - sparse_categorical_accuracy: 0.9196 - val_loss: 2.8173 - val_sparse_categorical_accuracy: 0.7097
# Epoch 102/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7970 - sparse_categorical_accuracy: 0.8817 - val_loss: 1.4386 - val_sparse_categorical_accuracy: 0.7097
# Epoch 103/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.7478 - sparse_categorical_accuracy: 0.9053 - val_loss: 1.5105 - val_sparse_categorical_accuracy: 0.6532
# Epoch 104/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6835 - sparse_categorical_accuracy: 0.9395 - val_loss: 1.7448 - val_sparse_categorical_accuracy: 0.6774
# Epoch 105/200
# 31/31 [==============================] - 2s 54ms/step - loss: 0.7789 - sparse_categorical_accuracy: 0.9091 - val_loss: 1.8145 - val_sparse_categorical_accuracy: 0.6694
# Epoch 106/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6847 - sparse_categorical_accuracy: 0.9369 - val_loss: 2.4177 - val_sparse_categorical_accuracy: 0.6452
# Epoch 107/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.7031 - sparse_categorical_accuracy: 0.9258 - val_loss: 1.4839 - val_sparse_categorical_accuracy: 0.6532
# Epoch 108/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7350 - sparse_categorical_accuracy: 0.9001 - val_loss: 1.8168 - val_sparse_categorical_accuracy: 0.6290
# Epoch 109/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7062 - sparse_categorical_accuracy: 0.9268 - val_loss: 2.0966 - val_sparse_categorical_accuracy: 0.7258
# Epoch 110/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.6982 - sparse_categorical_accuracy: 0.9433 - val_loss: 1.5577 - val_sparse_categorical_accuracy: 0.6774
# Epoch 111/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.7881 - sparse_categorical_accuracy: 0.8974 - val_loss: 1.5208 - val_sparse_categorical_accuracy: 0.7016
# Epoch 112/200
# 31/31 [==============================] - 1s 48ms/step - loss: 0.6904 - sparse_categorical_accuracy: 0.9347 - val_loss: 1.8180 - val_sparse_categorical_accuracy: 0.6935
# Epoch 113/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.7152 - sparse_categorical_accuracy: 0.9239 - val_loss: 1.9798 - val_sparse_categorical_accuracy: 0.6613
# Epoch 114/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6816 - sparse_categorical_accuracy: 0.9488 - val_loss: 2.9832 - val_sparse_categorical_accuracy: 0.6371
# Epoch 115/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.7060 - sparse_categorical_accuracy: 0.9209 - val_loss: 2.8605 - val_sparse_categorical_accuracy: 0.6774
# Epoch 116/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7266 - sparse_categorical_accuracy: 0.9268 - val_loss: 2.1940 - val_sparse_categorical_accuracy: 0.6048
# Epoch 117/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7728 - sparse_categorical_accuracy: 0.9056 - val_loss: 1.6962 - val_sparse_categorical_accuracy: 0.6935
# Epoch 118/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6703 - sparse_categorical_accuracy: 0.9506 - val_loss: 2.1126 - val_sparse_categorical_accuracy: 0.5968
# Epoch 119/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7496 - sparse_categorical_accuracy: 0.9108 - val_loss: 2.5809 - val_sparse_categorical_accuracy: 0.5806
# Epoch 120/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7054 - sparse_categorical_accuracy: 0.9432 - val_loss: 1.7641 - val_sparse_categorical_accuracy: 0.6290
# Epoch 121/200
# 31/31 [==============================] - 2s 61ms/step - loss: 0.7127 - sparse_categorical_accuracy: 0.9335 - val_loss: 1.9480 - val_sparse_categorical_accuracy: 0.6855
# Epoch 122/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.6784 - sparse_categorical_accuracy: 0.9439 - val_loss: 2.2532 - val_sparse_categorical_accuracy: 0.6532
# Epoch 123/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.7304 - sparse_categorical_accuracy: 0.9218 - val_loss: 2.7914 - val_sparse_categorical_accuracy: 0.6613
# Epoch 124/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7022 - sparse_categorical_accuracy: 0.9429 - val_loss: 2.1515 - val_sparse_categorical_accuracy: 0.6129
# Epoch 125/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7261 - sparse_categorical_accuracy: 0.9447 - val_loss: 1.6876 - val_sparse_categorical_accuracy: 0.7177
# Epoch 126/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6944 - sparse_categorical_accuracy: 0.9365 - val_loss: 1.6708 - val_sparse_categorical_accuracy: 0.6855
# Epoch 127/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6790 - sparse_categorical_accuracy: 0.9366 - val_loss: 1.7058 - val_sparse_categorical_accuracy: 0.5887
# Epoch 128/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6771 - sparse_categorical_accuracy: 0.9477 - val_loss: 1.5255 - val_sparse_categorical_accuracy: 0.6613
# Epoch 129/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7098 - sparse_categorical_accuracy: 0.9281 - val_loss: 1.6924 - val_sparse_categorical_accuracy: 0.6532
# Epoch 130/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6758 - sparse_categorical_accuracy: 0.9511 - val_loss: 1.8200 - val_sparse_categorical_accuracy: 0.6048
# Epoch 131/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6651 - sparse_categorical_accuracy: 0.9458 - val_loss: 1.7364 - val_sparse_categorical_accuracy: 0.7097
# Epoch 132/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6919 - sparse_categorical_accuracy: 0.9268 - val_loss: 1.5729 - val_sparse_categorical_accuracy: 0.7016
# Epoch 133/200
# 31/31 [==============================] - 2s 53ms/step - loss: 0.6819 - sparse_categorical_accuracy: 0.9351 - val_loss: 1.6059 - val_sparse_categorical_accuracy: 0.6129
# Epoch 134/200
# 31/31 [==============================] - 2s 53ms/step - loss: 0.6645 - sparse_categorical_accuracy: 0.9524 - val_loss: 1.4807 - val_sparse_categorical_accuracy: 0.7500
# Epoch 135/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6674 - sparse_categorical_accuracy: 0.9412 - val_loss: 2.2025 - val_sparse_categorical_accuracy: 0.6452
# Epoch 136/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.6342 - sparse_categorical_accuracy: 0.9573 - val_loss: 2.5819 - val_sparse_categorical_accuracy: 0.6210
# Epoch 137/200
# 31/31 [==============================] - 2s 55ms/step - loss: 0.6348 - sparse_categorical_accuracy: 0.9657 - val_loss: 1.9935 - val_sparse_categorical_accuracy: 0.6532
# Epoch 138/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6398 - sparse_categorical_accuracy: 0.9665 - val_loss: 1.8475 - val_sparse_categorical_accuracy: 0.6290
# Epoch 139/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.6486 - sparse_categorical_accuracy: 0.9523 - val_loss: 2.6206 - val_sparse_categorical_accuracy: 0.6452
# Epoch 140/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6574 - sparse_categorical_accuracy: 0.9526 - val_loss: 2.1099 - val_sparse_categorical_accuracy: 0.5726
# Epoch 141/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.6323 - sparse_categorical_accuracy: 0.9683 - val_loss: 2.0359 - val_sparse_categorical_accuracy: 0.6452
# Epoch 142/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6600 - sparse_categorical_accuracy: 0.9553 - val_loss: 2.5034 - val_sparse_categorical_accuracy: 0.6774
# Epoch 143/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7525 - sparse_categorical_accuracy: 0.9009 - val_loss: 2.1950 - val_sparse_categorical_accuracy: 0.6371
# Epoch 144/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6513 - sparse_categorical_accuracy: 0.9593 - val_loss: 1.7794 - val_sparse_categorical_accuracy: 0.6129
# Epoch 145/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.7138 - sparse_categorical_accuracy: 0.9256 - val_loss: 2.4473 - val_sparse_categorical_accuracy: 0.6532
# Epoch 146/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.6220 - sparse_categorical_accuracy: 0.9806 - val_loss: 2.1003 - val_sparse_categorical_accuracy: 0.5645
# Epoch 147/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6385 - sparse_categorical_accuracy: 0.9584 - val_loss: 2.8330 - val_sparse_categorical_accuracy: 0.6855
# Epoch 148/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.6765 - sparse_categorical_accuracy: 0.9438 - val_loss: 2.7189 - val_sparse_categorical_accuracy: 0.6210
# Epoch 149/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.6607 - sparse_categorical_accuracy: 0.9574 - val_loss: 2.9114 - val_sparse_categorical_accuracy: 0.6855
# Epoch 150/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6494 - sparse_categorical_accuracy: 0.9595 - val_loss: 3.7170 - val_sparse_categorical_accuracy: 0.6774
# Epoch 151/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.8444 - sparse_categorical_accuracy: 0.8915 - val_loss: 1.8865 - val_sparse_categorical_accuracy: 0.5484
# Epoch 152/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7163 - sparse_categorical_accuracy: 0.9314 - val_loss: 1.7122 - val_sparse_categorical_accuracy: 0.6371
# Epoch 153/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7327 - sparse_categorical_accuracy: 0.9395 - val_loss: 2.7924 - val_sparse_categorical_accuracy: 0.5645
# Epoch 154/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6514 - sparse_categorical_accuracy: 0.9655 - val_loss: 1.8825 - val_sparse_categorical_accuracy: 0.6855
# Epoch 155/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6604 - sparse_categorical_accuracy: 0.9544 - val_loss: 2.5800 - val_sparse_categorical_accuracy: 0.6129
# Epoch 156/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7278 - sparse_categorical_accuracy: 0.9366 - val_loss: 2.1440 - val_sparse_categorical_accuracy: 0.6290
# Epoch 157/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6860 - sparse_categorical_accuracy: 0.9424 - val_loss: 2.1772 - val_sparse_categorical_accuracy: 0.6290
# Epoch 158/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.7196 - sparse_categorical_accuracy: 0.9171 - val_loss: 2.4298 - val_sparse_categorical_accuracy: 0.6855
# Epoch 159/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6612 - sparse_categorical_accuracy: 0.9450 - val_loss: 1.6404 - val_sparse_categorical_accuracy: 0.6694
# Epoch 160/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.6366 - sparse_categorical_accuracy: 0.9654 - val_loss: 2.7539 - val_sparse_categorical_accuracy: 0.6452
# Epoch 161/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6693 - sparse_categorical_accuracy: 0.9555 - val_loss: 1.6876 - val_sparse_categorical_accuracy: 0.6452
# Epoch 162/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6600 - sparse_categorical_accuracy: 0.9511 - val_loss: 2.3039 - val_sparse_categorical_accuracy: 0.6613
# Epoch 163/200
# 31/31 [==============================] - 2s 61ms/step - loss: 0.6719 - sparse_categorical_accuracy: 0.9369 - val_loss: 2.5752 - val_sparse_categorical_accuracy: 0.5565
# Epoch 164/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.7686 - sparse_categorical_accuracy: 0.9271 - val_loss: 1.6941 - val_sparse_categorical_accuracy: 0.6855
# Epoch 165/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7085 - sparse_categorical_accuracy: 0.9207 - val_loss: 1.8701 - val_sparse_categorical_accuracy: 0.5887
# Epoch 166/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.9598 - val_loss: 2.2473 - val_sparse_categorical_accuracy: 0.6452
# Epoch 167/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6010 - sparse_categorical_accuracy: 0.9767 - val_loss: 2.3290 - val_sparse_categorical_accuracy: 0.6290
# Epoch 168/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6068 - sparse_categorical_accuracy: 0.9724 - val_loss: 1.8619 - val_sparse_categorical_accuracy: 0.6774
# Epoch 169/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6166 - sparse_categorical_accuracy: 0.9707 - val_loss: 2.7252 - val_sparse_categorical_accuracy: 0.6048
# Epoch 170/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6937 - sparse_categorical_accuracy: 0.9390 - val_loss: 2.5217 - val_sparse_categorical_accuracy: 0.6694
# Epoch 171/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6311 - sparse_categorical_accuracy: 0.9568 - val_loss: 1.9819 - val_sparse_categorical_accuracy: 0.5726
# Epoch 172/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6917 - sparse_categorical_accuracy: 0.9398 - val_loss: 1.8284 - val_sparse_categorical_accuracy: 0.6532
# Epoch 173/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6571 - sparse_categorical_accuracy: 0.9573 - val_loss: 1.9682 - val_sparse_categorical_accuracy: 0.5968
# Epoch 174/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6373 - sparse_categorical_accuracy: 0.9589 - val_loss: 2.2565 - val_sparse_categorical_accuracy: 0.5645
# Epoch 175/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6449 - sparse_categorical_accuracy: 0.9732 - val_loss: 1.9973 - val_sparse_categorical_accuracy: 0.6129
# Epoch 176/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.5894 - sparse_categorical_accuracy: 0.9770 - val_loss: 1.7138 - val_sparse_categorical_accuracy: 0.6613
# Epoch 177/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6213 - sparse_categorical_accuracy: 0.9587 - val_loss: 1.7347 - val_sparse_categorical_accuracy: 0.6774
# Epoch 178/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6701 - sparse_categorical_accuracy: 0.9417 - val_loss: 2.5893 - val_sparse_categorical_accuracy: 0.6613
# Epoch 179/200
# 31/31 [==============================] - 2s 61ms/step - loss: 0.6871 - sparse_categorical_accuracy: 0.9410 - val_loss: 1.7194 - val_sparse_categorical_accuracy: 0.6532
# Epoch 180/200
# 31/31 [==============================] - 2s 74ms/step - loss: 0.6064 - sparse_categorical_accuracy: 0.9821 - val_loss: 2.5285 - val_sparse_categorical_accuracy: 0.6532
# Epoch 181/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6585 - sparse_categorical_accuracy: 0.9562 - val_loss: 1.8532 - val_sparse_categorical_accuracy: 0.7500
# Epoch 182/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6454 - sparse_categorical_accuracy: 0.9534 - val_loss: 2.1986 - val_sparse_categorical_accuracy: 0.6935
# Epoch 183/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7153 - sparse_categorical_accuracy: 0.9320 - val_loss: 2.5770 - val_sparse_categorical_accuracy: 0.6210
# Epoch 184/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6425 - sparse_categorical_accuracy: 0.9510 - val_loss: 2.1576 - val_sparse_categorical_accuracy: 0.6452
# Epoch 185/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6659 - sparse_categorical_accuracy: 0.9529 - val_loss: 2.1981 - val_sparse_categorical_accuracy: 0.6694
# Epoch 186/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6143 - sparse_categorical_accuracy: 0.9690 - val_loss: 1.9076 - val_sparse_categorical_accuracy: 0.6774
# Epoch 187/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6616 - sparse_categorical_accuracy: 0.9514 - val_loss: 2.3057 - val_sparse_categorical_accuracy: 0.6371
# Epoch 188/200
# 31/31 [==============================] - 2s 61ms/step - loss: 0.6096 - sparse_categorical_accuracy: 0.9713 - val_loss: 2.3776 - val_sparse_categorical_accuracy: 0.6613
# Epoch 189/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6578 - sparse_categorical_accuracy: 0.9547 - val_loss: 1.8805 - val_sparse_categorical_accuracy: 0.6048
# Epoch 190/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6588 - sparse_categorical_accuracy: 0.9417 - val_loss: 3.1400 - val_sparse_categorical_accuracy: 0.6613
# Epoch 191/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6143 - sparse_categorical_accuracy: 0.9734 - val_loss: 2.2349 - val_sparse_categorical_accuracy: 0.6613
# Epoch 192/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6362 - sparse_categorical_accuracy: 0.9572 - val_loss: 2.7036 - val_sparse_categorical_accuracy: 0.6371
# Epoch 193/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6937 - sparse_categorical_accuracy: 0.9491 - val_loss: 1.6553 - val_sparse_categorical_accuracy: 0.6210
# Epoch 194/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6353 - sparse_categorical_accuracy: 0.9599 - val_loss: 2.2357 - val_sparse_categorical_accuracy: 0.6613
# Epoch 195/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6445 - sparse_categorical_accuracy: 0.9540 - val_loss: 1.6772 - val_sparse_categorical_accuracy: 0.6613
# Epoch 196/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6498 - sparse_categorical_accuracy: 0.9496 - val_loss: 3.7265 - val_sparse_categorical_accuracy: 0.5323
# Epoch 197/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6595 - sparse_categorical_accuracy: 0.9606 - val_loss: 2.1964 - val_sparse_categorical_accuracy: 0.6290
# Epoch 198/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.7269 - sparse_categorical_accuracy: 0.9273 - val_loss: 2.1782 - val_sparse_categorical_accuracy: 0.6855
# Epoch 199/200
# 31/31 [==============================] - 2s 64ms/step - loss: 0.6041 - sparse_categorical_accuracy: 0.9765 - val_loss: 2.9110 - val_sparse_categorical_accuracy: 0.5726
# Epoch 200/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6717 - sparse_categorical_accuracy: 0.9405 - val_loss: 2.0765 - val_sparse_categorical_accuracy: 0.6129

# %%
data = test_dataset.take(1)

points, labels = list(data)[0]
points = points[:1, ...]
labels = labels[:1, ...]

# run test data through model
preds = model.predict(points)
preds = tf.math.argmax(preds, -1)

points = points.numpy()

# plot points with predicted class and label
fig = plt.figure(figsize=(10, 10))
for i in range(1):
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(points[i, :, 0], points[i, :, 1], points[i, :, 2])
    ax.set_title(
        "pred: {:},\n label: {:},\n position: {:}".format(
            CLASS_MAP[preds[i].numpy()], CLASS_MAP[labels.numpy()[i]], i
        )
    )
    ax.set_axis_off()
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
display(len(classes))
# Out:
# 2

# %%
display(len(train_points))
# Out:
# 493
