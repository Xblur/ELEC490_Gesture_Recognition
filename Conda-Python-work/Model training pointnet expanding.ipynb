# %%
# Data Processing and model code
# import necessary packages

import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
import time
import datetime
from pathlib import Path
import glob

tf.random.set_seed(1234)

# path="wiki_crop/00"
# load dataset
with open("labaled_data.json", "r") as outfile:
            data = json.load(outfile)
        
with open("labaled_data.json", "r") as outfile:
    our_data = json.load(outfile)

data.update(our_data)
classes = set()
for i in data:
    classes.add(data.get(i)[1])
classes = list(classes)

# %%
# %matplotlib notebook
points = np.array(data.get(list(data.keys())[2])[0])
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(points[:, 0], points[:, 1], points[:, 2])
ax.set_axis_off()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
def parse_split_dataset(data, classes, num_points=478):

    train_points = []
    train_labels = []
    test_points = []
    test_labels = []
    class_map = classes

    for i in enumerate(list(data.keys())):
        if i[0] < int(len(list(data.keys()))*0.8):
            train_points.append(data.get(i[1])[0])
            train_labels.append(classes.index(data.get(i[1])[1]))
        else:
            test_points.append(data.get(i[1])[0])
            test_labels.append(classes.index(data.get(i[1])[1]))
        
    return (
        np.array(train_points),
        np.array(test_points),
        np.array(train_labels),
        np.array(test_labels),
        class_map,
    )

# %%
NUM_POINTS = 478
NUM_CLASSES = len(classes)
BATCH_SIZE = 16

train_points, test_points, train_labels, test_labels, CLASS_MAP = parse_split_dataset(data, classes, NUM_POINTS)

# %%
def augment(points, label):
    # jitter points
    points += tf.random.uniform(points.shape, -0.005, 0.005, dtype=tf.float64)
    # shuffle points
    points = tf.random.shuffle(points)
    return points, label


train_dataset = tf.data.Dataset.from_tensor_slices((train_points, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_points, test_labels))

train_dataset = train_dataset.shuffle(len(train_points)).map(augment).batch(BATCH_SIZE)
test_dataset = test_dataset.shuffle(len(test_points)).batch(BATCH_SIZE)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((None, 478, 3), (None,)), types: (tf.float64, tf.int32)>

# %%
def conv_bn(x, filters):
    x = layers.Conv1D(filters, kernel_size=1, padding="valid")(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)


def dense_bn(x, filters):
    x = layers.Dense(filters)(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)

# %%
class OrthogonalRegularizer(keras.regularizers.Regularizer):
    def __init__(self, num_features, l2reg=0.001):
        super().__init__()
        self.num_features = num_features
        self.l2reg = l2reg
        self.eye = tf.eye(num_features)

    def __call__(self, x):
        x = tf.reshape(x, (-1, self.num_features, self.num_features))
        xxt = tf.tensordot(x, x, axes=(2, 2))
        xxt = tf.reshape(xxt, (-1, self.num_features, self.num_features))
        return tf.reduce_sum(self.l2reg * tf.square(xxt - self.eye))
    
    def get_config(self):
        config = super().get_config()
        config.update({"num_features": self.num_features, "l2reg_strength": self.l2reg})
        return config

# %%
def tnet(inputs, num_features):

    # Initalise bias as the indentity matrix
    bias = keras.initializers.Constant(np.eye(num_features).flatten())
    reg = OrthogonalRegularizer(num_features)

    x = conv_bn(inputs, 32)
    x = conv_bn(x, 128)
    x = conv_bn(x, 256)
    x = conv_bn(x, 1028)
    x = layers.GlobalMaxPooling1D()(x)
    x = dense_bn(x, 512)
    x = dense_bn(x, 256)
    x = dense_bn(x, 128)
    x = layers.Dense(
        num_features * num_features,
        kernel_initializer="zeros",
        bias_initializer=bias,
        activity_regularizer=reg,
    )(x)
    feat_T = layers.Reshape((num_features, num_features))(x)
    # Apply affine transformation to input features
    return layers.Dot(axes=(2, 1))([inputs, feat_T])

# %%
#Point net model
inputs = keras.Input(shape=(NUM_POINTS, 3))

x = tnet(inputs, 3)
x = conv_bn(x, 32)
x = conv_bn(x, 32)
x = tnet(x, 32)
x = conv_bn(x, 32)
x = conv_bn(x, 64)
x = conv_bn(x, 128)
x = conv_bn(x, 512)
x = layers.GlobalMaxPooling1D()(x)
x = dense_bn(x, 512)
x = dense_bn(x, 256)
x = layers.Dropout(0.3)(x)
x = dense_bn(x, 128)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)
model_name = "./Pointnet_expanded_our2"
model = keras.Model(inputs=inputs, outputs=outputs, name=model_name)
model.summary()
# Out:
# Model: "./Pointnet_expanded_our1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 478, 3)]     0
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 478, 32)      128         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 478, 32)      128         conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 478, 32)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 478, 128)     4224        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 478, 128)     512         conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 478, 128)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 478, 256)     33024       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 478, 256)     1024        conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 478, 256)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 478, 1028)    264196      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 478, 1028)    4112        conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 478, 1028)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 1028)         0           activation_23[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 256)          263424      global_max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 256)          1024        dense_9[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 256)          0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          32896       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 128)          512         dense_10[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 128)          0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 9)            1161        activation_25[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 3, 3)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 478, 3)       0           input_2[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 478, 32)      128         dot_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 478, 32)      128         conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 478, 32)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 478, 32)      1056        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 478, 32)      128         conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 478, 32)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 478, 32)      1056        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 478, 32)      128         conv1d_20[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 478, 32)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 478, 128)     4224        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 478, 128)     512         conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 478, 128)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 478, 256)     33024       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 478, 256)     1024        conv1d_22[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 478, 256)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 478, 1028)    264196      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 478, 1028)    4112        conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 478, 1028)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 1028)         0           activation_31[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          263424      global_max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 256)          1024        dense_12[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 256)          0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          32896       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 128)          512         dense_13[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 128)          0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1024)         132096      activation_33[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 32, 32)       0           dense_14[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 478, 32)      0           activation_27[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 478, 32)      1056        dot_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 478, 32)      128         conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 478, 32)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 478, 64)      2112        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 478, 64)      256         conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 478, 64)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 478, 128)     8320        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 478, 128)     512         conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 478, 128)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 478, 512)     66048       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 478, 512)     2048        conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 478, 512)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 512)          0           activation_37[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          131328      global_max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 256)          1024        dense_15[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 256)          0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           activation_38[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 128)          32896       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128)          512         dense_16[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 128)          0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           activation_39[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 2)            258         dropout_3[0][0]
# ==================================================================================================
# Total params: 1,592,531
# Trainable params: 1,582,851
# Non-trainable params: 9,680
# __________________________________________________________________________________________________

# %%
try:
    model.load_weights(model_name)
except:
    print("no model data")

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=["sparse_categorical_accuracy"],
)

checkpoint_filepath = "./checkpoint_"+model_name

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_sparse_categorical_accuracy',
    mode='max',
    save_best_only=True)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + model_name
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
model.fit(train_dataset, epochs=200, validation_data=test_dataset, callbacks=[model_checkpoint_callback,tensorboard_callback])

# model.load_weights(checkpoint_filepath)
model.save_weights(model_name)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... <__main__.OrthogonalRegularizer object at 0x0000018E7BC76160> does not implement get_config()
# Epoch 1/200
# 31/31 [==============================] - 8s 107ms/step - loss: 0.7196 - sparse_categorical_accuracy: 0.9334 - val_loss: 1.9393 - val_sparse_categorical_accuracy: 0.7419
# Epoch 2/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7084 - sparse_categorical_accuracy: 0.9140 - val_loss: 1.5723 - val_sparse_categorical_accuracy: 0.6855
# Epoch 3/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6879 - sparse_categorical_accuracy: 0.9655 - val_loss: 2.3640 - val_sparse_categorical_accuracy: 0.6532
# Epoch 4/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.7638 - sparse_categorical_accuracy: 0.9166 - val_loss: 1.7909 - val_sparse_categorical_accuracy: 0.6855
# Epoch 5/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.6954 - sparse_categorical_accuracy: 0.9452 - val_loss: 1.8069 - val_sparse_categorical_accuracy: 0.6774
# Epoch 6/200
# 31/31 [==============================] - 2s 54ms/step - loss: 0.6133 - sparse_categorical_accuracy: 0.9534 - val_loss: 3.2454 - val_sparse_categorical_accuracy: 0.6371
# Epoch 7/200
# 31/31 [==============================] - 2s 54ms/step - loss: 0.6825 - sparse_categorical_accuracy: 0.9424 - val_loss: 2.2970 - val_sparse_categorical_accuracy: 0.6210
# Epoch 8/200
# 31/31 [==============================] - 2s 54ms/step - loss: 0.6707 - sparse_categorical_accuracy: 0.9511 - val_loss: 1.6822 - val_sparse_categorical_accuracy: 0.6774
# Epoch 9/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.6861 - sparse_categorical_accuracy: 0.9391 - val_loss: 1.4545 - val_sparse_categorical_accuracy: 0.7177
# Epoch 10/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7925 - sparse_categorical_accuracy: 0.9322 - val_loss: 1.8023 - val_sparse_categorical_accuracy: 0.6210
# Epoch 11/200
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6510 - sparse_categorical_accuracy: 0.9552 - val_loss: 1.9771 - val_sparse_categorical_accuracy: 0.6371
# Epoch 12/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6196 - sparse_categorical_accuracy: 0.9638 - val_loss: 1.9125 - val_sparse_categorical_accuracy: 0.6774
# Epoch 13/200
# 31/31 [==============================] - 2s 48ms/step - loss: 0.6823 - sparse_categorical_accuracy: 0.9390 - val_loss: 2.2917 - val_sparse_categorical_accuracy: 0.6532
# Epoch 14/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6320 - sparse_categorical_accuracy: 0.9634 - val_loss: 2.0275 - val_sparse_categorical_accuracy: 0.6290
# Epoch 15/200
# 31/31 [==============================] - 2s 55ms/step - loss: 0.6763 - sparse_categorical_accuracy: 0.9498 - val_loss: 1.8362 - val_sparse_categorical_accuracy: 0.6855
# Epoch 16/200
# 31/31 [==============================] - 2s 53ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.9528 - val_loss: 2.0984 - val_sparse_categorical_accuracy: 0.6371
# Epoch 17/200
# 31/31 [==============================] - 2s 53ms/step - loss: 0.7477 - sparse_categorical_accuracy: 0.9115 - val_loss: 2.2170 - val_sparse_categorical_accuracy: 0.6694
# Epoch 18/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.7268 - sparse_categorical_accuracy: 0.9163 - val_loss: 1.7552 - val_sparse_categorical_accuracy: 0.6452
# Epoch 19/200
# 31/31 [==============================] - 2s 50ms/step - loss: 0.6599 - sparse_categorical_accuracy: 0.9533 - val_loss: 2.4147 - val_sparse_categorical_accuracy: 0.6613
# Epoch 20/200
# 31/31 [==============================] - 2s 49ms/step - loss: 0.6424 - sparse_categorical_accuracy: 0.9538 - val_loss: 1.9913 - val_sparse_categorical_accuracy: 0.6694
# Epoch 21/200
# 31/31 [==============================] - 2s 55ms/step - loss: 0.6287 - sparse_categorical_accuracy: 0.9680 - val_loss: 1.9405 - val_sparse_categorical_accuracy: 0.6774
# Epoch 22/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6565 - sparse_categorical_accuracy: 0.9491 - val_loss: 1.5067 - val_sparse_categorical_accuracy: 0.7016
# Epoch 23/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6247 - sparse_categorical_accuracy: 0.9702 - val_loss: 2.0204 - val_sparse_categorical_accuracy: 0.6694
# Epoch 24/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6872 - sparse_categorical_accuracy: 0.9431 - val_loss: 1.7865 - val_sparse_categorical_accuracy: 0.6694
# Epoch 25/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7243 - sparse_categorical_accuracy: 0.9410 - val_loss: 1.8569 - val_sparse_categorical_accuracy: 0.6532
# Epoch 26/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6469 - sparse_categorical_accuracy: 0.9707 - val_loss: 1.4269 - val_sparse_categorical_accuracy: 0.7016
# Epoch 27/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6443 - sparse_categorical_accuracy: 0.9670 - val_loss: 1.3043 - val_sparse_categorical_accuracy: 0.6774
# Epoch 28/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.9481 - val_loss: 2.1581 - val_sparse_categorical_accuracy: 0.6452
# Epoch 29/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.7159 - sparse_categorical_accuracy: 0.9187 - val_loss: 2.7394 - val_sparse_categorical_accuracy: 0.6371
# Epoch 30/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7374 - sparse_categorical_accuracy: 0.9302 - val_loss: 1.6235 - val_sparse_categorical_accuracy: 0.6855
# Epoch 31/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6266 - sparse_categorical_accuracy: 0.9587 - val_loss: 2.3528 - val_sparse_categorical_accuracy: 0.6452
# Epoch 32/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6007 - sparse_categorical_accuracy: 0.9738 - val_loss: 1.9225 - val_sparse_categorical_accuracy: 0.6774
# Epoch 33/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6349 - sparse_categorical_accuracy: 0.9575 - val_loss: 1.7879 - val_sparse_categorical_accuracy: 0.6855
# Epoch 34/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6874 - sparse_categorical_accuracy: 0.9416 - val_loss: 1.8362 - val_sparse_categorical_accuracy: 0.6452
# Epoch 35/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6837 - sparse_categorical_accuracy: 0.9401 - val_loss: 2.1191 - val_sparse_categorical_accuracy: 0.7177
# Epoch 36/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6506 - sparse_categorical_accuracy: 0.9585 - val_loss: 1.6710 - val_sparse_categorical_accuracy: 0.6774
# Epoch 37/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6372 - sparse_categorical_accuracy: 0.9615 - val_loss: 2.7058 - val_sparse_categorical_accuracy: 0.6290
# Epoch 38/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6610 - sparse_categorical_accuracy: 0.9473 - val_loss: 1.5051 - val_sparse_categorical_accuracy: 0.7419
# Epoch 39/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6264 - sparse_categorical_accuracy: 0.9582 - val_loss: 1.8910 - val_sparse_categorical_accuracy: 0.6774
# Epoch 40/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6074 - sparse_categorical_accuracy: 0.9800 - val_loss: 2.0842 - val_sparse_categorical_accuracy: 0.6774
# Epoch 41/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6348 - sparse_categorical_accuracy: 0.9560 - val_loss: 1.8014 - val_sparse_categorical_accuracy: 0.6694
# Epoch 42/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.7565 - sparse_categorical_accuracy: 0.9551 - val_loss: 3.0458 - val_sparse_categorical_accuracy: 0.6210
# Epoch 43/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6364 - sparse_categorical_accuracy: 0.9578 - val_loss: 2.5223 - val_sparse_categorical_accuracy: 0.6694
# Epoch 44/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6131 - sparse_categorical_accuracy: 0.9740 - val_loss: 2.4410 - val_sparse_categorical_accuracy: 0.7097
# Epoch 45/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6319 - sparse_categorical_accuracy: 0.9664 - val_loss: 1.8376 - val_sparse_categorical_accuracy: 0.6855
# Epoch 46/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6396 - sparse_categorical_accuracy: 0.9632 - val_loss: 2.1438 - val_sparse_categorical_accuracy: 0.7016
# Epoch 47/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6758 - sparse_categorical_accuracy: 0.9591 - val_loss: 1.9593 - val_sparse_categorical_accuracy: 0.6452
# Epoch 48/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6861 - sparse_categorical_accuracy: 0.9409 - val_loss: 2.7566 - val_sparse_categorical_accuracy: 0.6613
# Epoch 49/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7817 - sparse_categorical_accuracy: 0.9325 - val_loss: 3.4099 - val_sparse_categorical_accuracy: 0.6452
# Epoch 50/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6888 - sparse_categorical_accuracy: 0.9466 - val_loss: 1.5627 - val_sparse_categorical_accuracy: 0.7419
# Epoch 51/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7005 - sparse_categorical_accuracy: 0.9325 - val_loss: 1.5749 - val_sparse_categorical_accuracy: 0.7177
# Epoch 52/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7061 - sparse_categorical_accuracy: 0.9305 - val_loss: 1.6694 - val_sparse_categorical_accuracy: 0.6048
# Epoch 53/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6412 - sparse_categorical_accuracy: 0.9611 - val_loss: 1.9012 - val_sparse_categorical_accuracy: 0.6613
# Epoch 54/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6237 - sparse_categorical_accuracy: 0.9712 - val_loss: 2.1863 - val_sparse_categorical_accuracy: 0.6774
# Epoch 55/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6383 - sparse_categorical_accuracy: 0.9491 - val_loss: 1.8664 - val_sparse_categorical_accuracy: 0.6452
# Epoch 56/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7001 - sparse_categorical_accuracy: 0.9368 - val_loss: 2.4978 - val_sparse_categorical_accuracy: 0.6935
# Epoch 57/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6507 - sparse_categorical_accuracy: 0.9379 - val_loss: 1.6561 - val_sparse_categorical_accuracy: 0.7661
# Epoch 58/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.5863 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.8477 - val_sparse_categorical_accuracy: 0.6935
# Epoch 59/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6397 - sparse_categorical_accuracy: 0.9604 - val_loss: 1.5628 - val_sparse_categorical_accuracy: 0.7661
# Epoch 60/200
# 31/31 [==============================] - 2s 54ms/step - loss: 0.6685 - sparse_categorical_accuracy: 0.9349 - val_loss: 2.0758 - val_sparse_categorical_accuracy: 0.6694
# Epoch 61/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.7235 - sparse_categorical_accuracy: 0.9252 - val_loss: 1.5920 - val_sparse_categorical_accuracy: 0.6694
# Epoch 62/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6285 - sparse_categorical_accuracy: 0.9668 - val_loss: 1.6129 - val_sparse_categorical_accuracy: 0.7177
# Epoch 63/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6642 - sparse_categorical_accuracy: 0.9431 - val_loss: 1.6941 - val_sparse_categorical_accuracy: 0.7258
# Epoch 64/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6638 - sparse_categorical_accuracy: 0.9535 - val_loss: 2.5374 - val_sparse_categorical_accuracy: 0.6935
# Epoch 65/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6259 - sparse_categorical_accuracy: 0.9728 - val_loss: 1.6619 - val_sparse_categorical_accuracy: 0.7016
# Epoch 66/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.9663 - val_loss: 3.1218 - val_sparse_categorical_accuracy: 0.6452
# Epoch 67/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6725 - sparse_categorical_accuracy: 0.9499 - val_loss: 1.7954 - val_sparse_categorical_accuracy: 0.7339
# Epoch 68/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6404 - sparse_categorical_accuracy: 0.9597 - val_loss: 1.6899 - val_sparse_categorical_accuracy: 0.7258
# Epoch 69/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.5996 - sparse_categorical_accuracy: 0.9746 - val_loss: 1.8922 - val_sparse_categorical_accuracy: 0.6855
# Epoch 70/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6017 - sparse_categorical_accuracy: 0.9668 - val_loss: 1.3798 - val_sparse_categorical_accuracy: 0.7903
# Epoch 71/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6121 - sparse_categorical_accuracy: 0.9614 - val_loss: 2.1902 - val_sparse_categorical_accuracy: 0.6774
# Epoch 72/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6030 - sparse_categorical_accuracy: 0.9642 - val_loss: 1.8382 - val_sparse_categorical_accuracy: 0.7097
# Epoch 73/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6192 - sparse_categorical_accuracy: 0.9674 - val_loss: 2.7613 - val_sparse_categorical_accuracy: 0.6694
# Epoch 74/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6906 - sparse_categorical_accuracy: 0.9543 - val_loss: 1.5926 - val_sparse_categorical_accuracy: 0.6855
# Epoch 75/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7268 - sparse_categorical_accuracy: 0.9288 - val_loss: 1.8200 - val_sparse_categorical_accuracy: 0.7258
# Epoch 76/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.9656 - val_loss: 2.4128 - val_sparse_categorical_accuracy: 0.7097
# Epoch 77/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.5945 - sparse_categorical_accuracy: 0.9768 - val_loss: 1.6415 - val_sparse_categorical_accuracy: 0.7097
# Epoch 78/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6752 - sparse_categorical_accuracy: 0.9530 - val_loss: 1.7772 - val_sparse_categorical_accuracy: 0.6371
# Epoch 79/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7336 - sparse_categorical_accuracy: 0.9477 - val_loss: 2.0433 - val_sparse_categorical_accuracy: 0.6774
# Epoch 80/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6160 - sparse_categorical_accuracy: 0.9682 - val_loss: 2.0639 - val_sparse_categorical_accuracy: 0.6613
# Epoch 81/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6225 - sparse_categorical_accuracy: 0.9619 - val_loss: 1.5987 - val_sparse_categorical_accuracy: 0.7258
# Epoch 82/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6673 - sparse_categorical_accuracy: 0.9457 - val_loss: 1.9294 - val_sparse_categorical_accuracy: 0.6935
# Epoch 83/200
# 31/31 [==============================] - 2s 71ms/step - loss: 0.6162 - sparse_categorical_accuracy: 0.9642 - val_loss: 2.3055 - val_sparse_categorical_accuracy: 0.7016
# Epoch 84/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.5972 - sparse_categorical_accuracy: 0.9779 - val_loss: 1.7457 - val_sparse_categorical_accuracy: 0.6855
# Epoch 85/200
# 31/31 [==============================] - 2s 54ms/step - loss: 0.6690 - sparse_categorical_accuracy: 0.9466 - val_loss: 2.1418 - val_sparse_categorical_accuracy: 0.6532
# Epoch 86/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.7114 - sparse_categorical_accuracy: 0.9259 - val_loss: 2.1461 - val_sparse_categorical_accuracy: 0.6774
# Epoch 87/200
# 31/31 [==============================] - 1s 46ms/step - loss: 0.7307 - sparse_categorical_accuracy: 0.9231 - val_loss: 1.6764 - val_sparse_categorical_accuracy: 0.7097
# Epoch 88/200
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6432 - sparse_categorical_accuracy: 0.9539 - val_loss: 3.4389 - val_sparse_categorical_accuracy: 0.6210
# Epoch 89/200
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6845 - sparse_categorical_accuracy: 0.9356 - val_loss: 1.6559 - val_sparse_categorical_accuracy: 0.7097
# Epoch 90/200
# 31/31 [==============================] - 2s 55ms/step - loss: 0.6983 - sparse_categorical_accuracy: 0.9428 - val_loss: 1.7290 - val_sparse_categorical_accuracy: 0.6935
# Epoch 91/200
# 31/31 [==============================] - 2s 52ms/step - loss: 0.6333 - sparse_categorical_accuracy: 0.9547 - val_loss: 1.4607 - val_sparse_categorical_accuracy: 0.7419
# Epoch 92/200
# 31/31 [==============================] - 2s 54ms/step - loss: 0.5847 - sparse_categorical_accuracy: 0.9825 - val_loss: 1.6464 - val_sparse_categorical_accuracy: 0.6290
# Epoch 93/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6338 - sparse_categorical_accuracy: 0.9600 - val_loss: 2.0967 - val_sparse_categorical_accuracy: 0.6129
# Epoch 94/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6194 - sparse_categorical_accuracy: 0.9680 - val_loss: 2.0626 - val_sparse_categorical_accuracy: 0.7016
# Epoch 95/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6433 - sparse_categorical_accuracy: 0.9610 - val_loss: 1.5307 - val_sparse_categorical_accuracy: 0.6532
# Epoch 96/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5967 - sparse_categorical_accuracy: 0.9720 - val_loss: 1.9636 - val_sparse_categorical_accuracy: 0.6290
# Epoch 97/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6602 - sparse_categorical_accuracy: 0.9517 - val_loss: 1.9778 - val_sparse_categorical_accuracy: 0.6210
# Epoch 98/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6287 - sparse_categorical_accuracy: 0.9633 - val_loss: 2.1277 - val_sparse_categorical_accuracy: 0.7339
# Epoch 99/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5977 - sparse_categorical_accuracy: 0.9778 - val_loss: 2.3939 - val_sparse_categorical_accuracy: 0.6613
# Epoch 100/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5874 - sparse_categorical_accuracy: 0.9803 - val_loss: 2.0762 - val_sparse_categorical_accuracy: 0.6855
# Epoch 101/200
# 31/31 [==============================] - 2s 65ms/step - loss: 0.6642 - sparse_categorical_accuracy: 0.9460 - val_loss: 1.6257 - val_sparse_categorical_accuracy: 0.7500
# Epoch 102/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6599 - sparse_categorical_accuracy: 0.9545 - val_loss: 1.8201 - val_sparse_categorical_accuracy: 0.7419
# Epoch 103/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.5989 - sparse_categorical_accuracy: 0.9748 - val_loss: 2.5451 - val_sparse_categorical_accuracy: 0.6694
# Epoch 104/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6032 - sparse_categorical_accuracy: 0.9686 - val_loss: 1.9259 - val_sparse_categorical_accuracy: 0.6774
# Epoch 105/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6713 - sparse_categorical_accuracy: 0.9477 - val_loss: 2.6000 - val_sparse_categorical_accuracy: 0.5968
# Epoch 106/200
# 31/31 [==============================] - 2s 75ms/step - loss: 1.2668 - sparse_categorical_accuracy: 0.7933 - val_loss: 1.3618 - val_sparse_categorical_accuracy: 0.6532
# Epoch 107/200
# 31/31 [==============================] - 2s 57ms/step - loss: 1.0073 - sparse_categorical_accuracy: 0.7712 - val_loss: 4.1758 - val_sparse_categorical_accuracy: 0.6774
# Epoch 108/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8906 - sparse_categorical_accuracy: 0.8363 - val_loss: 4.9594 - val_sparse_categorical_accuracy: 0.5726
# Epoch 109/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8587 - sparse_categorical_accuracy: 0.8777 - val_loss: 12.7173 - val_sparse_categorical_accuracy: 0.5484
# Epoch 110/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.8123 - sparse_categorical_accuracy: 0.8658 - val_loss: 2.0122 - val_sparse_categorical_accuracy: 0.6290
# Epoch 111/200
# 31/31 [==============================] - 2s 78ms/step - loss: 0.7672 - sparse_categorical_accuracy: 0.8936 - val_loss: 1.1056 - val_sparse_categorical_accuracy: 0.7339
# Epoch 112/200
# 31/31 [==============================] - 2s 79ms/step - loss: 0.6993 - sparse_categorical_accuracy: 0.9398 - val_loss: 1.4024 - val_sparse_categorical_accuracy: 0.7258
# Epoch 113/200
# 31/31 [==============================] - 2s 67ms/step - loss: 0.6386 - sparse_categorical_accuracy: 0.9663 - val_loss: 3.3955 - val_sparse_categorical_accuracy: 0.6774
# Epoch 114/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7283 - sparse_categorical_accuracy: 0.9417 - val_loss: 4.1390 - val_sparse_categorical_accuracy: 0.5726
# Epoch 115/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.8597 - sparse_categorical_accuracy: 0.8764 - val_loss: 2.0130 - val_sparse_categorical_accuracy: 0.7097
# Epoch 116/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.8277 - sparse_categorical_accuracy: 0.8712 - val_loss: 1.3424 - val_sparse_categorical_accuracy: 0.7339
# Epoch 117/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7497 - sparse_categorical_accuracy: 0.8968 - val_loss: 1.8296 - val_sparse_categorical_accuracy: 0.6774
# Epoch 118/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6811 - sparse_categorical_accuracy: 0.9489 - val_loss: 1.7281 - val_sparse_categorical_accuracy: 0.6855
# Epoch 119/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6801 - sparse_categorical_accuracy: 0.9424 - val_loss: 2.8429 - val_sparse_categorical_accuracy: 0.6613
# Epoch 120/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6625 - sparse_categorical_accuracy: 0.9600 - val_loss: 13.4347 - val_sparse_categorical_accuracy: 0.6532
# Epoch 121/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6833 - sparse_categorical_accuracy: 0.9540 - val_loss: 1.6923 - val_sparse_categorical_accuracy: 0.6371
# Epoch 122/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6515 - sparse_categorical_accuracy: 0.9533 - val_loss: 2.1581 - val_sparse_categorical_accuracy: 0.6532
# Epoch 123/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6836 - sparse_categorical_accuracy: 0.9485 - val_loss: 2.6501 - val_sparse_categorical_accuracy: 0.5887
# Epoch 124/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6674 - sparse_categorical_accuracy: 0.9558 - val_loss: 1.6799 - val_sparse_categorical_accuracy: 0.6210
# Epoch 125/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6493 - sparse_categorical_accuracy: 0.9421 - val_loss: 1.5465 - val_sparse_categorical_accuracy: 0.7177
# Epoch 126/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6445 - sparse_categorical_accuracy: 0.9543 - val_loss: 1.9667 - val_sparse_categorical_accuracy: 0.6613
# Epoch 127/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7319 - sparse_categorical_accuracy: 0.9367 - val_loss: 1.7778 - val_sparse_categorical_accuracy: 0.6048
# Epoch 128/200
# 31/31 [==============================] - 2s 55ms/step - loss: 0.6397 - sparse_categorical_accuracy: 0.9587 - val_loss: 1.3457 - val_sparse_categorical_accuracy: 0.7419
# Epoch 129/200
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6524 - sparse_categorical_accuracy: 0.9526 - val_loss: 1.7480 - val_sparse_categorical_accuracy: 0.6855
# Epoch 130/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6044 - sparse_categorical_accuracy: 0.9793 - val_loss: 2.6148 - val_sparse_categorical_accuracy: 0.5806
# Epoch 131/200
# 31/31 [==============================] - 2s 61ms/step - loss: 0.6755 - sparse_categorical_accuracy: 0.9549 - val_loss: 1.9699 - val_sparse_categorical_accuracy: 0.6371
# Epoch 132/200
# 31/31 [==============================] - 2s 63ms/step - loss: 0.6260 - sparse_categorical_accuracy: 0.9545 - val_loss: 2.0458 - val_sparse_categorical_accuracy: 0.6774
# Epoch 133/200
# 31/31 [==============================] - 3s 91ms/step - loss: 0.5969 - sparse_categorical_accuracy: 0.9789 - val_loss: 3.3413 - val_sparse_categorical_accuracy: 0.6048
# Epoch 134/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6509 - sparse_categorical_accuracy: 0.9563 - val_loss: 1.7822 - val_sparse_categorical_accuracy: 0.7097
# Epoch 135/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7076 - sparse_categorical_accuracy: 0.9288 - val_loss: 1.6108 - val_sparse_categorical_accuracy: 0.7258
# Epoch 136/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6646 - sparse_categorical_accuracy: 0.9483 - val_loss: 1.6870 - val_sparse_categorical_accuracy: 0.7419
# Epoch 137/200
# 31/31 [==============================] - 2s 72ms/step - loss: 0.6519 - sparse_categorical_accuracy: 0.9541 - val_loss: 1.8525 - val_sparse_categorical_accuracy: 0.7016
# Epoch 138/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6483 - sparse_categorical_accuracy: 0.9674 - val_loss: 1.9859 - val_sparse_categorical_accuracy: 0.6694
# Epoch 139/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.5882 - sparse_categorical_accuracy: 0.9793 - val_loss: 2.4989 - val_sparse_categorical_accuracy: 0.6613
# Epoch 140/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.5869 - sparse_categorical_accuracy: 0.9830 - val_loss: 2.3541 - val_sparse_categorical_accuracy: 0.7419
# Epoch 141/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6005 - sparse_categorical_accuracy: 0.9759 - val_loss: 1.5513 - val_sparse_categorical_accuracy: 0.6532
# Epoch 142/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6335 - sparse_categorical_accuracy: 0.9555 - val_loss: 2.5375 - val_sparse_categorical_accuracy: 0.7016
# Epoch 143/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6770 - sparse_categorical_accuracy: 0.9520 - val_loss: 2.1640 - val_sparse_categorical_accuracy: 0.6210
# Epoch 144/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6413 - sparse_categorical_accuracy: 0.9638 - val_loss: 1.6836 - val_sparse_categorical_accuracy: 0.7016
# Epoch 145/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6308 - sparse_categorical_accuracy: 0.9605 - val_loss: 1.6954 - val_sparse_categorical_accuracy: 0.6694
# Epoch 146/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6034 - sparse_categorical_accuracy: 0.9735 - val_loss: 1.8903 - val_sparse_categorical_accuracy: 0.6774
# Epoch 147/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.5646 - sparse_categorical_accuracy: 0.9873 - val_loss: 2.0207 - val_sparse_categorical_accuracy: 0.7016
# Epoch 148/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6020 - sparse_categorical_accuracy: 0.9814 - val_loss: 1.9323 - val_sparse_categorical_accuracy: 0.7258
# Epoch 149/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6452 - sparse_categorical_accuracy: 0.9586 - val_loss: 1.7083 - val_sparse_categorical_accuracy: 0.6694
# Epoch 150/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6731 - sparse_categorical_accuracy: 0.9458 - val_loss: 1.6088 - val_sparse_categorical_accuracy: 0.6613
# Epoch 151/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7018 - sparse_categorical_accuracy: 0.9356 - val_loss: 1.7204 - val_sparse_categorical_accuracy: 0.6694
# Epoch 152/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6672 - sparse_categorical_accuracy: 0.9469 - val_loss: 1.8776 - val_sparse_categorical_accuracy: 0.7016
# Epoch 153/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6856 - sparse_categorical_accuracy: 0.9382 - val_loss: 1.6467 - val_sparse_categorical_accuracy: 0.6935
# Epoch 154/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6232 - sparse_categorical_accuracy: 0.9658 - val_loss: 2.0205 - val_sparse_categorical_accuracy: 0.7258
# Epoch 155/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6199 - sparse_categorical_accuracy: 0.9675 - val_loss: 2.5159 - val_sparse_categorical_accuracy: 0.6290
# Epoch 156/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.5999 - sparse_categorical_accuracy: 0.9780 - val_loss: 2.9723 - val_sparse_categorical_accuracy: 0.6694
# Epoch 157/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6395 - sparse_categorical_accuracy: 0.9600 - val_loss: 1.4682 - val_sparse_categorical_accuracy: 0.6935
# Epoch 158/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6187 - sparse_categorical_accuracy: 0.9592 - val_loss: 2.3739 - val_sparse_categorical_accuracy: 0.6371
# Epoch 159/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6393 - sparse_categorical_accuracy: 0.9523 - val_loss: 1.9075 - val_sparse_categorical_accuracy: 0.6774
# Epoch 160/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6441 - sparse_categorical_accuracy: 0.9549 - val_loss: 2.1303 - val_sparse_categorical_accuracy: 0.7016
# Epoch 161/200
# 31/31 [==============================] - 2s 62ms/step - loss: 0.6213 - sparse_categorical_accuracy: 0.9632 - val_loss: 2.2985 - val_sparse_categorical_accuracy: 0.5968
# Epoch 162/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6667 - sparse_categorical_accuracy: 0.9583 - val_loss: 1.7576 - val_sparse_categorical_accuracy: 0.6855
# Epoch 163/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6536 - sparse_categorical_accuracy: 0.9663 - val_loss: 1.9750 - val_sparse_categorical_accuracy: 0.6452
# Epoch 164/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5964 - sparse_categorical_accuracy: 0.9747 - val_loss: 1.6415 - val_sparse_categorical_accuracy: 0.7500
# Epoch 165/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5975 - sparse_categorical_accuracy: 0.9664 - val_loss: 2.0045 - val_sparse_categorical_accuracy: 0.6935
# Epoch 166/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5808 - sparse_categorical_accuracy: 0.9797 - val_loss: 1.9484 - val_sparse_categorical_accuracy: 0.6532
# Epoch 167/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6385 - sparse_categorical_accuracy: 0.9566 - val_loss: 2.0011 - val_sparse_categorical_accuracy: 0.6613
# Epoch 168/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6233 - sparse_categorical_accuracy: 0.9675 - val_loss: 2.6828 - val_sparse_categorical_accuracy: 0.7016
# Epoch 169/200
# 31/31 [==============================] - 3s 91ms/step - loss: 0.6186 - sparse_categorical_accuracy: 0.9698 - val_loss: 2.1951 - val_sparse_categorical_accuracy: 0.7016
# Epoch 170/200
# 31/31 [==============================] - 5s 173ms/step - loss: 0.6583 - sparse_categorical_accuracy: 0.9534 - val_loss: 2.1634 - val_sparse_categorical_accuracy: 0.6452
# Epoch 171/200
# 31/31 [==============================] - 3s 84ms/step - loss: 0.5802 - sparse_categorical_accuracy: 0.9824 - val_loss: 2.0020 - val_sparse_categorical_accuracy: 0.6855
# Epoch 172/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.5791 - sparse_categorical_accuracy: 0.9750 - val_loss: 1.7668 - val_sparse_categorical_accuracy: 0.7016
# Epoch 173/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6136 - sparse_categorical_accuracy: 0.9761 - val_loss: 1.8382 - val_sparse_categorical_accuracy: 0.6935
# Epoch 174/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.5707 - sparse_categorical_accuracy: 0.9887 - val_loss: 1.8933 - val_sparse_categorical_accuracy: 0.6290
# Epoch 175/200
# 31/31 [==============================] - 3s 83ms/step - loss: 0.5982 - sparse_categorical_accuracy: 0.9662 - val_loss: 1.8725 - val_sparse_categorical_accuracy: 0.7097
# Epoch 176/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5953 - sparse_categorical_accuracy: 0.9659 - val_loss: 2.7868 - val_sparse_categorical_accuracy: 0.6452
# Epoch 177/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6329 - sparse_categorical_accuracy: 0.9525 - val_loss: 2.3171 - val_sparse_categorical_accuracy: 0.6613
# Epoch 178/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6416 - sparse_categorical_accuracy: 0.9606 - val_loss: 1.7199 - val_sparse_categorical_accuracy: 0.7258
# Epoch 179/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5886 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.5464 - val_sparse_categorical_accuracy: 0.6774
# Epoch 180/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6233 - sparse_categorical_accuracy: 0.9695 - val_loss: 2.2418 - val_sparse_categorical_accuracy: 0.7177
# Epoch 181/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.5671 - sparse_categorical_accuracy: 0.9927 - val_loss: 2.8367 - val_sparse_categorical_accuracy: 0.6452
# Epoch 182/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6085 - sparse_categorical_accuracy: 0.9668 - val_loss: 2.3568 - val_sparse_categorical_accuracy: 0.6774
# Epoch 183/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6157 - sparse_categorical_accuracy: 0.9629 - val_loss: 2.0286 - val_sparse_categorical_accuracy: 0.6774
# Epoch 184/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6907 - sparse_categorical_accuracy: 0.9539 - val_loss: 1.5947 - val_sparse_categorical_accuracy: 0.7339
# Epoch 185/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6089 - sparse_categorical_accuracy: 0.9757 - val_loss: 2.1069 - val_sparse_categorical_accuracy: 0.7097
# Epoch 186/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6009 - sparse_categorical_accuracy: 0.9654 - val_loss: 2.6932 - val_sparse_categorical_accuracy: 0.7258
# Epoch 187/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6124 - sparse_categorical_accuracy: 0.9657 - val_loss: 2.1499 - val_sparse_categorical_accuracy: 0.7419
# Epoch 188/200
# 31/31 [==============================] - 2s 56ms/step - loss: 0.6624 - sparse_categorical_accuracy: 0.9642 - val_loss: 1.4968 - val_sparse_categorical_accuracy: 0.7419
# Epoch 189/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6956 - sparse_categorical_accuracy: 0.9405 - val_loss: 1.9053 - val_sparse_categorical_accuracy: 0.5565
# Epoch 190/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.7428 - sparse_categorical_accuracy: 0.9131 - val_loss: 1.4281 - val_sparse_categorical_accuracy: 0.7016
# Epoch 191/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.5987 - sparse_categorical_accuracy: 0.9728 - val_loss: 2.5695 - val_sparse_categorical_accuracy: 0.6935
# Epoch 192/200
# 31/31 [==============================] - 2s 57ms/step - loss: 0.6803 - sparse_categorical_accuracy: 0.9387 - val_loss: 2.4330 - val_sparse_categorical_accuracy: 0.6532
# Epoch 193/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.7660 - sparse_categorical_accuracy: 0.8901 - val_loss: 6.8800 - val_sparse_categorical_accuracy: 0.6774
# Epoch 194/200
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6074 - sparse_categorical_accuracy: 0.9778 - val_loss: 2.0670 - val_sparse_categorical_accuracy: 0.6694
# Epoch 195/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6413 - sparse_categorical_accuracy: 0.9532 - val_loss: 4.3967 - val_sparse_categorical_accuracy: 0.5806
# Epoch 196/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.5965 - sparse_categorical_accuracy: 0.9839 - val_loss: 2.3963 - val_sparse_categorical_accuracy: 0.6774
# Epoch 197/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6101 - sparse_categorical_accuracy: 0.9669 - val_loss: 1.6707 - val_sparse_categorical_accuracy: 0.7339
# Epoch 198/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6173 - sparse_categorical_accuracy: 0.9678 - val_loss: 2.7967 - val_sparse_categorical_accuracy: 0.6532
# Epoch 199/200
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6342 - sparse_categorical_accuracy: 0.9663 - val_loss: 3.7499 - val_sparse_categorical_accuracy: 0.5806
# Epoch 200/200
# 31/31 [==============================] - 2s 58ms/step - loss: 0.6384 - sparse_categorical_accuracy: 0.9546 - val_loss: 2.0080 - val_sparse_categorical_accuracy: 0.6371

# %%
data = test_dataset.take(1)

points, labels = list(data)[0]
points = points[:1, ...]
labels = labels[:1, ...]

# run test data through model
preds = model.predict(points)
preds = tf.math.argmax(preds, -1)

points = points.numpy()

# plot points with predicted class and label
fig = plt.figure(figsize=(10, 10))
for i in range(1):
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(points[i, :, 0], points[i, :, 1], points[i, :, 2])
    ax.set_title(
        "pred: {:},\n label: {:},\n position: {:}".format(
            CLASS_MAP[preds[i].numpy()], CLASS_MAP[labels.numpy()[i]], i
        )
    )
    ax.set_axis_off()
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
display(len(classes))
# Out:
# 2

# %%
display(len(train_points))
# Out:
# 9
