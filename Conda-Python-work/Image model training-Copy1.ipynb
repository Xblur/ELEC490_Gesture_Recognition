# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
import numpy as np
import matplotlib.pyplot as plt
import h5py
import random
import json
import datetime

# %%
# load the data
file_name = "./Data/all_labeled_images_data.h5"

base_dir = "./"+file_name

with open("./Our_images/Capstone/our_images_labaled_data.json", "r") as outfile:
    pointcloud_data = json.load(outfile)

classes = ['LookLeft', 'LookRight', 'LookUp', 'Neutral', 'RaiseEyebrows', 'Smile', 'OpenMouth']

# %%
# Split data into training, testing and validation. Create tensorflow dataset instances for each.
SPLIT_RATIO = 0.7
with h5py.File(file_name, "r") as file:
    c = list(zip(list(file['images']),list(file['labels'])))
    sz = len(c)
    cut_training = int(sz*SPLIT_RATIO)
    cut_test_val = int(((sz-cut_training)*0.5) + cut_training)
    random.shuffle(c)
    
#     print("sz:" + str(sz))
#     print("cut_test_val:" + str(cut_test_val))
    training=c[:cut_training]
    testing=c[cut_training:cut_test_val]
    validation = c[cut_test_val:]
    
    training_data=[]
    training_labels=[]
    testing_data=[]
    testing_labels=[]
    validation_data=[]
    validation_labels=[]
    
    for a in training:
        training_data.append(a[0])
        training_labels.append(a[1])

    for a in testing:
        testing_data.append(a[0])
        testing_labels.append(a[1])

    for a in validation:
        validation_data.append(a[0])
        validation_labels.append(a[1])

training_x=np.array(training_data)
training_labels=np.array(training_labels)
training_data = tf.data.Dataset.from_tensor_slices((training_x, training_labels))
testing_x=np.array(testing_data)
testing_labels=np.array(testing_labels)
testing_data = tf.data.Dataset.from_tensor_slices((testing_x, testing_labels))
val_x=np.array(validation_data)
val_labels=np.array(validation_labels)
val_data = tf.data.Dataset.from_tensor_slices((val_x, val_labels))
display(training_data, testing_data, val_data)
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(255, 255, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(), dtype=tf.uint8, name=None))>
# <TensorSliceDataset element_spec=(TensorSpec(shape=(255, 255, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(), dtype=tf.uint8, name=None))>
# <TensorSliceDataset element_spec=(TensorSpec(shape=(255, 255, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(), dtype=tf.uint8, name=None))>

# %%
# import time
# class ArtificialDataset(tf.data.Dataset):
#     def _generator(num_samples):
#         # Opening the file
#         time.sleep(0.03)

#         for sample_idx in range(num_samples):
#             # Reading data (line, record) from the file
#             time.sleep(0.015)

#             yield (sample_idx,)

#     def __new__(cls, num_samples=3):
#         return tf.data.Dataset.from_generator(
#             cls._generator,
#             output_signature = tf.TensorSpec(shape = (1,), dtype = tf.int64),
#             args=(num_samples,)
#         )

# %%
# def benchmark(dataset, num_epochs=2):
#     start_time = time.perf_counter()
#     for epoch_num in range(num_epochs):
#         for sample in dataset:
#             # Performing a training step
#             time.sleep(0.01)
#     print("Execution time:", time.perf_counter() - start_time)

# %%
# benchmark(
#     ArtificialDataset()
#     .prefetch(tf.data.AUTOTUNE)
# )

# %%
# prefetch the images and augment them randomly to learn features better. 

IMAGE_SIZE = 255

BATCH_SIZE = 32

input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)

data_augmentation = tf.keras.Sequential([
    layers.RandomBrightness(0.8),
    layers.RandomContrast(0.8),
    layers.RandomRotation(0.6)
])

aug_ds = training_data.map(
  lambda x, y: (data_augmentation(x, training=True), y))
test_ds = testing_data.map(
  lambda x, y: (data_augmentation(x, training=True), y))

aug_ds = aug_ds.cache().shuffle(3000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

aug_ds = aug_ds.batch(BATCH_SIZE, num_parallel_calls=tf.data.AUTOTUNE).repeat()
test_ds = test_ds.batch(BATCH_SIZE, num_parallel_calls=tf.data.AUTOTUNE)

# Create the model
inputs = keras.Input(shape=input_shape)
num_classes = len(classes)

x = layers.Rescaling(1.0 / IMAGE_SIZE)(inputs)  # Rescale and normalize inputs

base_model = keras.applications.ResNet50V2(  # Add the rest of the model
    weights=None, input_shape=input_shape, classes=num_classes, pooling="avg"
)(x)

dropout = tf.keras.layers.Dropout(0.15)
base_model = dropout(base_model)
model_name = "RESNET50V2_our_data_contrast_brightness_avg_pooling_0_03"

model = keras.Model(inputs, base_model, name=model_name)

model.compile(optimizer=keras.optimizers.experimental.RMSprop(learning_rate=0.05), 
                loss="sparse_categorical_crossentropy", 
                metrics=[keras.metrics.SparseCategoricalAccuracy()])

# data_generator.fit(training_data)

# display(training_data.shape)
# display(training_labels.shape)

# for image_batch, label_batch in train_generator:
#     break

# %%
# load if model name already exists
try:
    model.load_weights("./checkpoint_/best_"+ model_name)
except:
    print("no weights")

# %%
# train the model
logdir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + model_name
checkpoint_filepath = "./checkpoint_/best_"+model_name

early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='sparse_categorical_accuracy',
    mode='max',
    save_best_only=True)

#use with resnet to reduce overfitting
# def scheduler(epoch, lr):
#     if epoch < 60:
#         return lr
#     else:
# #         print("learning rate: " + lr)
#         return lr * tf.math.exp(-0.1)

# learning_rate_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)

history = model.fit(aug_ds, 
                    epochs=500,
                    batch_size=BATCH_SIZE,
                    validation_data=test_ds,
                    callbacks=[model_checkpoint_callback,tensorboard_callback, early_stopping_callback, learning_rate_callback], 
                    steps_per_epoch=30,
                    shuffle=True,
#                     initial_epoch=58,
#                     validation_steps=10,
                    validation_batch_size=BATCH_SIZE,
                    workers=10,
                    use_multiprocessing=True
                    )
# Out:
# Epoch 1/500
# 30/30 [==============================] - 53s 753ms/step - loss: 12.3286 - sparse_categorical_accuracy: 0.1312 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 2/500
# 30/30 [==============================] - 10s 346ms/step - loss: 11.8293 - sparse_categorical_accuracy: 0.1437 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 3/500
# 30/30 [==============================] - 11s 362ms/step - loss: 12.0319 - sparse_categorical_accuracy: 0.1458 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 4/500
# 30/30 [==============================] - 11s 371ms/step - loss: 11.8513 - sparse_categorical_accuracy: 0.1552 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 5/500
# 30/30 [==============================] - 9s 312ms/step - loss: 12.0583 - sparse_categorical_accuracy: 0.1333 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 6/500
# 30/30 [==============================] - 9s 315ms/step - loss: 12.1969 - sparse_categorical_accuracy: 0.1510 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 7/500
# 30/30 [==============================] - 10s 338ms/step - loss: 12.4493 - sparse_categorical_accuracy: 0.1354 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 8/500
# 30/30 [==============================] - 9s 293ms/step - loss: 12.2482 - sparse_categorical_accuracy: 0.1333 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 9/500
# 30/30 [==============================] - 9s 298ms/step - loss: 12.1353 - sparse_categorical_accuracy: 0.1417 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 10/500
# 30/30 [==============================] - 9s 295ms/step - loss: 12.2085 - sparse_categorical_accuracy: 0.1302 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 11/500
# 30/30 [==============================] - 9s 297ms/step - loss: 12.4081 - sparse_categorical_accuracy: 0.1301 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 12/500
# 30/30 [==============================] - 9s 290ms/step - loss: 12.7669 - sparse_categorical_accuracy: 0.1229 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 13/500
# 30/30 [==============================] - 9s 296ms/step - loss: 12.0004 - sparse_categorical_accuracy: 0.1490 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 14/500
# 30/30 [==============================] - 9s 291ms/step - loss: 12.1173 - sparse_categorical_accuracy: 0.1271 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 15/500
# 30/30 [==============================] - 9s 295ms/step - loss: 12.1984 - sparse_categorical_accuracy: 0.1417 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 16/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.2568 - sparse_categorical_accuracy: 0.1354 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 17/500
# 30/30 [==============================] - 9s 292ms/step - loss: 11.5413 - sparse_categorical_accuracy: 0.1521 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 18/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.3576 - sparse_categorical_accuracy: 0.1292 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 19/500
# 30/30 [==============================] - 9s 294ms/step - loss: 11.9775 - sparse_categorical_accuracy: 0.1479 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 20/500
# 30/30 [==============================] - 9s 291ms/step - loss: 12.0146 - sparse_categorical_accuracy: 0.1406 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 21/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.1816 - sparse_categorical_accuracy: 0.1396 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 22/500
# 30/30 [==============================] - 9s 290ms/step - loss: 12.1696 - sparse_categorical_accuracy: 0.1333 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 23/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.3388 - sparse_categorical_accuracy: 0.1312 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 24/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.1642 - sparse_categorical_accuracy: 0.1385 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 25/500
# 30/30 [==============================] - 9s 291ms/step - loss: 12.0649 - sparse_categorical_accuracy: 0.1375 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 26/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.2360 - sparse_categorical_accuracy: 0.1365 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 27/500
# 30/30 [==============================] - 9s 291ms/step - loss: 11.7795 - sparse_categorical_accuracy: 0.1521 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 28/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.0855 - sparse_categorical_accuracy: 0.1458 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 29/500
# 30/30 [==============================] - 9s 291ms/step - loss: 12.1327 - sparse_categorical_accuracy: 0.1333 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 30/500
# 30/30 [==============================] - 9s 292ms/step - loss: 11.9790 - sparse_categorical_accuracy: 0.1437 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 31/500
# 30/30 [==============================] - 9s 294ms/step - loss: 12.5362 - sparse_categorical_accuracy: 0.1219 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 32/500
# 30/30 [==============================] - 9s 298ms/step - loss: 11.9535 - sparse_categorical_accuracy: 0.1375 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 33/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.1974 - sparse_categorical_accuracy: 0.1323 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 34/500
# 30/30 [==============================] - 9s 294ms/step - loss: 12.2803 - sparse_categorical_accuracy: 0.1323 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 35/500
# 30/30 [==============================] - 9s 293ms/step - loss: 12.2421 - sparse_categorical_accuracy: 0.1302 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 36/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.0904 - sparse_categorical_accuracy: 0.1312 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 37/500
# 30/30 [==============================] - 9s 292ms/step - loss: 12.0131 - sparse_categorical_accuracy: 0.1396 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 38/500
# 30/30 [==============================] - 9s 297ms/step - loss: 11.8299 - sparse_categorical_accuracy: 0.1521 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 39/500
# 30/30 [==============================] - 9s 292ms/step - loss: 11.9865 - sparse_categorical_accuracy: 0.1333 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 40/500
# 30/30 [==============================] - 9s 295ms/step - loss: 12.1272 - sparse_categorical_accuracy: 0.1427 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 41/500
# 30/30 [==============================] - 9s 290ms/step - loss: 12.2864 - sparse_categorical_accuracy: 0.1333 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 42/500
# 30/30 [==============================] - 9s 293ms/step - loss: 12.1159 - sparse_categorical_accuracy: 0.1354 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 43/500
# 30/30 [==============================] - 9s 291ms/step - loss: 12.3032 - sparse_categorical_accuracy: 0.1375 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 44/500
# 30/30 [==============================] - 9s 294ms/step - loss: 11.9936 - sparse_categorical_accuracy: 0.1462 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 45/500
# 30/30 [==============================] - 9s 294ms/step - loss: 12.0950 - sparse_categorical_accuracy: 0.1469 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 46/500
# 30/30 [==============================] - 9s 301ms/step - loss: 12.1871 - sparse_categorical_accuracy: 0.1344 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 47/500
# 30/30 [==============================] - 9s 291ms/step - loss: 12.1353 - sparse_categorical_accuracy: 0.1344 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 48/500
# 30/30 [==============================] - 9s 294ms/step - loss: 12.2482 - sparse_categorical_accuracy: 0.1312 - val_loss: 13.7967 - val_sparse_categorical_accuracy: 0.1440 - lr: 0.0061
# Epoch 49/500
# 26/30 [=========================>....] - ETA: 0s - loss: 12.2911 - sparse_categorical_accuracy: 0.1262
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 24
#      20 learning_rate_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
#      22 tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)
# ---> 24 history = model.fit(aug_ds,
#      25                     epochs=500,
#      26                     batch_size=BATCH_SIZE,
#      27                     validation_data=test_ds,
#      28                     callbacks=[model_checkpoint_callback,tensorboard_callback, early_stopping_callback, learning_rate_callback],
#      29                     steps_per_epoch=30,
#      30                     shuffle=True,
#      31 #                     initial_epoch=58,
#      32 #                     validation_steps=10,
#      33                     validation_batch_size=BATCH_SIZE,
#      34                     workers=10,
#      35                     use_multiprocessing=True
#      36                     )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save_weights("./weights/last_"+ model_name)

# %%
#save weights as .json for react
# weights = model.get_weights()

# weights_json = [w.tolist() for w in weights]

# with open("jsmodelweights.json", "w") as outfile:
#     json.dump(weights_json, outfile)

# %%
#save best validation accuracy model
try:
    model.load_weights("./checkpoint_/best_"+ model_name)
except:
    print("no weights")
model_filepath = "./model/best_"+model_name
model.save(model_filepath)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 54). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./model/best_RESNET50V2_our_data_contrast_brightness_avg_pooling_0_03\assets
# INFO:tensorflow:Assets written to: ./model/best_RESNET50V2_our_data_contrast_brightness_avg_pooling_0_03\assets

# %%
#save last model weights
try:
    model.load_weights("./weights/last_"+ model_name)
except:
    print("no weights")
model_filepath = "./model/last_"+model_name
model.save(model_filepath)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./model/last_RESNET50V2_our_data_full_augment_avg_pooling_e-2\assets
# INFO:tensorflow:Assets written to: ./model/last_RESNET50V2_our_data_full_augment_avg_pooling_e-2\assets

# %%
model_name = "Okay model for demo"
model_filepath = "./model/"+model_name
model = tf.keras.models.load_model(model_filepath)

# %%
# Evaluatre the model on the validation dataset
# model.load_weights("./checkpoint_/best_"+ model_name)
IMAGE_SIZE = 255

BATCH_SIZE = 32

input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
val_ds = val_data.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE, num_parallel_calls=tf.data.AUTOTUNE)

results = model.evaluate(val_ds, batch_size=BATCH_SIZE)
print("test loss, test acc:", results)
# Out:
# 70/70 [==============================] - 8s 40ms/step - loss: 0.5770 - sparse_categorical_accuracy: 0.9303
# test loss, test acc: [0.5769848227500916, 0.9302852153778076]

# %%
#check a single image from the testing data

index_start = 1
index_end = index_start+1
predictions = model.predict(testing_x[index_start:index_end])
print("classes:")
print(classes)
print("predictions shape:", predictions.shape)
print("predictions:", predictions)
print("actual:", testing_labels[index_start:index_end])
predClassID = np.argmax(predictions)
predClassName = classes[predClassID]
print("prediction:", predClassName)
actClassID = testing_labels[index_start:index_end][0]
actClassName = classes[actClassID]
print("actual:", actClassName)
plt.imshow(testing_x[index_start], interpolation='nearest')
plt.show()
# Out:
# 1/1 [==============================] - 1s 507ms/step
# classes:
# ['LookLeft', 'LookRight', 'LookUp', 'Neutral', 'RaiseEyebrows', 'Smile', 'OpenMouth']
# predictions shape: (1, 7)
# predictions: [[1.3795965e-18 1.5669181e-25 3.4359698e-14 1.0000000e+00 1.1694839e-08
#   1.5091129e-15 1.5079668e-31]]
# actual: [3]
# prediction: Neutral
# actual: Neutral

# %%
# Print a group of images with labels
fig, axes = plt.subplots(4, 4, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(validation_data[i], interpolation='nearest')
    ax.set_axis_off()
    ax.set_title(classes[val_labels[i]])
plt.tight_layout()
plt.show()

# %%
# Create a confusion matrix
y_pred = model.predict(val_ds)

confusion_mtx = tf.math.confusion_matrix(val_labels, y_pred.argmax(axis=1))

# Convert the confusion matrix to a NumPy array
confusion_mtx = confusion_mtx.numpy()

# Plot the confusion matrix
plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 70/70 [==============================] - 3s 36ms/step

# %%
# Create a class distribution histogram

labels = np.concatenate((training_labels, testing_labels, validation_labels))
unique_labels, label_counts = np.unique(labels, return_counts=True)

# Plot the label distribution as a bar chart
plt.bar(classes, label_counts, width=0.7)
plt.xlabel('Class Label')
plt.ylabel('Label Count')
plt.title('Label Distribution')
plt.xticks(rotation=45, ha='right')
plt.show()
